# %%
import soundfile as sf
import matplotlib.pyplot as plt

f_name = 'sounddata.h'
f = open(f_name, 'w')

max_len = []

def func(i, max_len):
    names = '1'
    if(i == -2):
        names = 'sample'
    if(i == -1):
        names = 'Start_of_transmission'
    elif(i == 26):
        names = 'End_of_transmission'
    else:
        names = '' + str(i)

    soundfile = names+'.wav'
    soundfile_path = 'C:/Users/ulgeo/OneDrive/Desktop/Voice_numbers/WAV/'+soundfile

    data_in, datasamplerate = sf.read(soundfile_path)
    # This means stereo so extract one channel 0
    if len(data_in.shape)>1:
        data_in = data_in[:,0]

    import samplerate
    converter = 'sinc_best'  # or 'sinc_fastest', ...
    desired_sample_rate = 11000.0
    ratio = desired_sample_rate/datasamplerate
    data_out = samplerate.resample(data_in, ratio, converter)
    maxValue = max(data_out)
    minValue = min(data_out)
    vrange = (maxValue - minValue) 

    m68code = "/*    File "+soundfile+ "\r\n *    Sample rate "+str(int(desired_sample_rate)) +" Hz\r\n */\r\n"
    
    max_len.append(len(data_out))
    
    if(names == 'sample'):
        m68code += "#define WAV_DATA_LENGTH "+str(len(data_out))+" \r\n"
        m68code += "#define WAV_DATA WAV_DATA_" +names +"\r\n"
    
    if(names == 'Start_of_transmission'):
        m68code += "#define len_s "+str(len(data_out))+" \r\n"
        m68code += "#define samp_s WAV_DATA_" +names +"\r\n"
    elif(names == 'End_of_transmission'):
        m68code += "#define len_e "+str(len(data_out))+" \r\n"
        m68code += "#define samp_e WAV_DATA_" +names +"\r\n"
    else:
        m68code += "#define len_"+names+" "+str(len(data_out))+" \r\n"
        m68code += "#define samp_" +names +" WAV_DATA_" +names +"\r\n"

    m68code += "uint8_t WAV_DATA_" +names+ "[] = {\r\n    "

    maxitemsperline = 64
    itemsonline = maxitemsperline
    firstvalue = 0
    lastvalue = 0
    for v in data_out:
        # scale v to between 0 and 1
        isin = (v-minValue)/vrange   
        v =  int((isin * 255))
        vstr = str(v)
        if (firstvalue==0):
            firstvalue= v
        lastvalue = v
        m68code+=vstr
        itemsonline-=1
        if (itemsonline>0):
            m68code+=','
        else:
            itemsonline = maxitemsperline
            m68code+=',\n    '

    # keep track of first and last values to avoid
    # blip when the loop restarts.. make the end value
    # the average of the first and last. 
    end_value = int( (firstvalue + lastvalue) / 2)
    m68code+=str(end_value)+'    \r\n}; //'+ names +'\r\n'
    f.write(m68code)

for i in range(-2,27):
    func(i, max_len)
    
f.close()

print(max(max_len))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-680168fa0319> in <module>
#      77
#      78 for i in range(-2,27):
# ---> 79     func(i, max_len)
#      80
#      81 f.close()
#
# <ipython-input-17-680168fa0319> in func(i, max_len)
#      19     soundfile_path = 'C:/Users/ulgeo/OneDrive/Desktop/Voice_numbers/WAV/'+soundfile
#      20
# ---> 21     data_in, datasamplerate = sf.read(soundfile_path)
#      22     # This means stereo so extract one channel 0
#      23     if len(data_in.shape)>1:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\soundfile.py in read(file, frames, start, stop, dtype, always_2d, fill_value, out, samplerate, channels, format, subtype, endian, closefd)
#     254
#     255     """
# --> 256     with SoundFile(file, 'r', samplerate, channels,
#     257                    subtype, endian, format, closefd) as f:
#     258         frames = f._prepare_read(start, stop, frames)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\soundfile.py in __init__(self, file, mode, samplerate, channels, subtype, endian, format, closefd)
#     627         self._info = _create_info_struct(file, mode, samplerate, channels,
#     628                                          format, subtype, endian)
# --> 629         self._file = self._open(file, mode_int, closefd)
#     630         if set(mode).issuperset('r+') and self.seekable():
#     631             # Move write position to 0 (like in Python file objects)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\soundfile.py in _open(self, file, mode_int, closefd)
#    1181         else:
#    1182             raise TypeError("Invalid file: {0!r}".format(self.name))
# -> 1183         _error_check(_snd.sf_error(file_ptr),
#    1184                      "Error opening {0!r}: ".format(self.name))
#    1185         if mode_int == _snd.SFM_WRITE:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\soundfile.py in _error_check(err, prefix)
#    1355     if err != 0:
#    1356         err_str = _snd.sf_error_number(err)
# -> 1357         raise RuntimeError(prefix + _ffi.string(err_str).decode('utf-8', 'replace'))
#    1358
#    1359
#
# RuntimeError: Error opening 'C:/Users/ulgeo/OneDrive/Desktop/Voice_numbers/WAV/-2.wav': System error.
